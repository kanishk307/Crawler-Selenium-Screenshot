# %%
#Imports
import time
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import urllib.request
from urllib.request import urlopen
import pyautogui
from requests.exceptions import ConnectionError
# from pywebcopy import save_webpage

# %%
internal_urls = set()
external_urls = set()

# %%
def is_url_valid(url):
   #Checks if the url is valid or not
    parsedURL = urlparse(url)
    return bool(parsedURL.netloc) and bool(parsedURL.scheme)

#The above function works as follows. We check if the scheme is present and there is a value in the network location part
# url = "https://umd.edu/virusinfo"
# urlparse(url)
# ParseResult(scheme='https', netloc='umd.edu', path='/virusinfo', 
# params='', query='', fragment='')

# %%
#The function gives all urls
def get_all_urls(url):
    urls = set()
    # domain name of the URL without the protocol (umd.edu in this case)
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            #href is empty and we don't need that a element
            continue
        #if the link is not absolute, make it by joining relative to the base
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        #constructing an absolute URL from parsed data
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_url_valid(href):
            #in valid url
            continue
        if href in internal_urls:
            #it is already in the set, so we don't need to add
            continue
        if domain_name not in href:
            #it is an external link. i.e
            # Check if it is already there 
            if href not in external_urls:
#                 print(f"[EXT] External link: {href}")
                external_urls.add(href)
            continue
#         print(".",end=" ")
        print(f"[INT] Internal link: {href}")

        urls.add(href)
        internal_urls.add(href)
    return urls

# %%
total_urls_visited = 0
def crawl(url, max_urls=50):
    #Max URL is just to decrease the time if there are a lot of pages.
    #The following code was openly available of github and I found this
    #idea useful to inhibit crawling time
    global total_urls_visited
    total_urls_visited += 1
    try:
        links = get_all_urls(url)
        for link in links:
            if total_urls_visited > max_urls:
                break
            crawl(link, max_urls=max_urls)
    except:
        print("caught")

# %%
#base_url = "https://umd.edu/virusinfo"
#Input
# base_url = input("Enter the URL : ")
base_url = "https://www.okcu.edu/main/coronavirus/"
internal_urls.add(base_url)

# %%
parsedurl = urlparse(base_url)
print(parsedurl)
base_url_main = parsedurl.scheme+"://"+parsedurl.netloc
print(base_url_main)
# base_url_text = base_url.split("//",1)[1]
base_url_text = parsedurl.netloc+parsedurl.path
print(base_url_text)
# base_url_text_domain = base_url_text.split("/",1)[0]
base_url_text_domain = parsedurl.netloc
print(base_url_text_domain)
# Out:
# ParseResult(scheme='https', netloc='www.okcu.edu', path='/main/coronavirus/', params='', query='', fragment='')
# https://www.okcu.edu
# www.okcu.edu/main/coronavirus/
# www.okcu.edu

# %%
# internal_urls

# %%
crawl(base_url)
print("[+] Total External links:", len(external_urls))
print("[+] Total Internal links:", len(internal_urls))
print("[+] Total:", len(external_urls) + len(internal_urls))
# Out:
# [INT] Internal link: https://www.okcu.edu/
# [INT] Internal link: https://www.okcu.edu/main/about/
# [INT] Internal link: https://www.okcu.edu/main/about/quickfacts/
# [INT] Internal link: https://www.okcu.edu/main/about/history/
# [INT] Internal link: https://www.okcu.edu/main/about/mission/
# [INT] Internal link: https://www.okcu.edu/main/about/almamater/
# [INT] Internal link: https://www.okcu.edu/main/spotlight/
# [INT] Internal link: https://www.okcu.edu/main/tickets/
# [INT] Internal link: https://www.okcu.edu/main/veterans/
# [INT] Internal link: https://www.okcu.edu/main/veterans/why-ocu/
# [INT] Internal link: https://www.okcu.edu/main/veterans/degrees/
# [INT] Internal link: https://www.okcu.edu/main/veterans/mag/
# [INT] Internal link: https://www.okcu.edu/main/veterans/people/
# [INT] Internal link: https://www.okcu.edu/main/veterans/yellow-ribbon/
# [INT] Internal link: https://www.okcu.edu/main/veterans/resources/
# [INT] Internal link: https://www.okcu.edu/main/veterans/request-info/
# [INT] Internal link: https://www.okcu.edu/main/veterans/faq/
# [INT] Internal link: https://www.okcu.edu/main/veterans/contact-us/
# [INT] Internal link: https://www.okcu.edu/main/visitors/
# [INT] Internal link: https://www.okcu.edu/main/visitors/upcoming-events/
# [INT] Internal link: https://www.okcu.edu/main/visitors/schedule/
# [INT] Internal link: https://www.okcu.edu/main/visitors/experience-ocu/
# [INT] Internal link: https://www.okcu.edu/main/visitors/contact/
# [INT] Internal link: https://www.okcu.edu/main/visitors/map/
# [INT] Internal link: https://www.okcu.edu/main/visitors/group-visit/
# [INT] Internal link: https://www.okcu.edu/main/visitors/group-visit/request/
# [INT] Internal link: https://www.okcu.edu/main/visitors/group-visit/questions/
# [INT] Internal link: https://www.okcu.edu/main/visitors/okc/
# [INT] Internal link: https://www.okcu.edu/main/visitors/lodging/
# [INT] Internal link: https://www.okcu.edu/main/visitors/tour/
# [INT] Internal link: https://www.okcu.edu/main/visitors/guest-wifi/
# [INT] Internal link: https://www.okcu.edu/main/visitors/tour-guides/
# [INT] Internal link: https://www.okcu.edu/main/ways-to-give/
# [INT] Internal link: https://www.okcu.edu/main/weather/
# [INT] Internal link: https://www.okcu.edu/admissions/apply/
# [INT] Internal link: https://www.okcu.edu/admissions/requestinfo/
# [INT] Internal link: https://www.okcu.edu/financialaid/home/
# [INT] Internal link: https://www.okcu.edu/alumni/home/
# [INT] Internal link: https://www.okcu.edu/advancement/development/
# [INT] Internal link: https://www.okcu.edu/main/standalone/2020-return-to-campus-faq/
# [INT] Internal link: https://www.okcu.edu/admin/hr/jobs/
# [INT] Internal link: https://www.okcu.edu/admin/communications/media/
# [INT] Internal link: https://www.okcu.edu/admin/hr/eeoc/
# [INT] Internal link: https://www.okcu.edu/campus/home/
# [INT] Internal link: https://www.okcu.edu/campus/libraries/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/emergency-move-out/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/emergency-move-out/summer-storage/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/emergency-move-out/housing-move-out-proxy-authorization/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/apply/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/apply/accommodation/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/apply/exemption/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/apply/returning-students/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/apply/summer-housing/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/rates/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/rates/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/walker/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/banning/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/draper/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/methodist/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/residence-halls/cokesbury-apartments/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/housing-policies/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/work-order/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/laundry-view/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/roommates/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/services/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/safety/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/where-to-eat/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/living-on-campus/what-to-bring/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/staff/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/accommodations/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/dining/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/extra-facilities/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/insurance/
# [INT] Internal link: https://www.okcu.edu/campus/residencelife/camps_conferences/attractions/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/about/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/worship/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/about-the-chapel/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/about-the-chapel/chapel-50th-anniversary/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/student-groups/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life/area-churches/
# [INT] Internal link: https://www.okcu.edu/campus/religious-life

# [INT] Internal link: https://www.okcu.edu/students/diversity-inclusion/student-organizations/saudi-student-association/
# [INT] Internal link: https://www.okcu.edu/students/diversity-inclusion/student-organizations/spectrum/
# [INT] Internal link: https://www.okcu.edu/students/diversity-inclusion/contact-us/
# [INT] Internal link: https://www.okcu.edu/students/diversity-inclusion/clara-luper-scholarship/
# [INT] Internal link: https://www.okcu.edu/students/diversity-inclusion/american-indian-scholarship/
# [INT] Internal link: https://www.okcu.edu/students/student-affairs-staff/
# [INT] Internal link: https://www.okcu.edu/students/stars101/
# [INT] Internal link: https://www.okcu.edu/students/travel/
# [INT] Internal link: https://www.okcu.edu/students/career-services/career-internship-and-grad-studies-fairs/career-internship-grad-studies-fair/
# [INT] Internal link: https://www.okcu.edu/news/expert-sources/
# [INT] Internal link: https://www.okcu.edu/directory/john-starkey/
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Mentoring-Agreement.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Icebreaker-Questions.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Questions-to-Ask-Your-Mentor.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Goal-Setting-Worksheet.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Goal-Tracking-Worksheet.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/Mentors-How-to-get-started.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [INT] Internal link: https://www.okcu.edu/uploads/Conduct-Records-Release-Authorization-Form-2019-v2.0.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/personal-statements.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [INT] Internal link: https://www.okcu.edu/students/career-services/students/internships/steps-to-a-successful-search/{entry:7711:url}
# [INT] Internal link: https://www.okcu.edu/uploads/students/career-services/docs/job-search-tracking-Tool.xlsx
# [INT] Internal link: https://www.okcu.edu/students/career-services/career-internship-and-grad-studies-fairs/
# [+] Total External links: 82
# [+] Total Internal links: 1106
# [+] Total: 1188

# %%
count = 0
last_count = 989874
immediate_urls = set() #Linked Associated with the current page, https://umd.edu/virusinfo/ in this case

for i in range(0,4):
    for url in internal_urls:
        if base_url_text in url:
            immediate_urls.add(url)
    count = len(immediate_urls)
    print(count,i)
    if(count == last_count):
        break
    last_count = count
    for immediate_url in immediate_urls:
        try:
            crawl(immediate_url)
            print("[+] NEW Total External links:", len(external_urls))
            print("[+] NEW Total Internal links:", len(internal_urls))
            print("[+] NEW Total:", len(external_urls) + len(internal_urls))
            if len(internal_urls)>1000:
                break
        except requests.exceptions.ConnectionError:
            continue
# Out:
# 28 0
# [+] NEW Total External links: 83
# [+] NEW Total Internal links: 1106
# [+] NEW Total: 1189
# [INT] Internal link: https://www.okcu.edu/uploads/students/OCU-CARES-Emergency-Grant-Email-Messaging.pdf
# [INT] Internal link: https://www.okcu.edu/onlinegiving/development/emergency-care/
# [+] NEW Total External links: 83
# [+] NEW Total Internal links: 1108
# [+] NEW Total: 1191
# [+] NEW Total External links: 84
# [+] NEW Total Internal links: 1108
# [+] NEW Total: 1192
# [INT] Internal link: https://www.okcu.edu/academics/calendar/2020-2021/
# [+] NEW Total External links: 93
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1202
# [+] NEW Total External links: 94
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1203
# [+] NEW Total External links: 94
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1203
# [+] NEW Total External links: 97
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1206
# [+] NEW Total External links: 97
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1206
# [+] NEW Total External links: 102
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1211
# [+] NEW Total External links: 103
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1212
# [+] NEW Total External links: 103
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1212
# [+] NEW Total External links: 103
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1212
# [+] NEW Total External links: 110
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1219
# [+] NEW Total External links: 112
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1221
# [+] NEW Total External links: 112
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1221
# [+] NEW Total External links: 116
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1225
# [+] NEW Total External links: 116
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1225
# [+] NEW Total External links: 116
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1225
# [+] NEW Total External links: 116
# [+] NEW Total Internal links: 1109
# [+] NEW Total: 1225
# [INT] Internal link: https://www.okcu.edu/uploads/campus/cetl/Zoom-Tip-Sheet.pdf
# [INT] Internal link: https://www.okcu.edu/campus/resources/cetl/resources/cetl-blog/
# [INT] Internal link: https://www.okcu.edu/uploads/campus/technology/VPN-Instructions.pdf
# [+] NEW Total External links: 149
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1261
# [+] NEW Total External links: 149
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1261
# [+] NEW Total External links: 151
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1263
# [+] NEW Total External links: 151
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1263
# [+] NEW Total External links: 151
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1263
# [+] NEW Total External links: 153
# [+] NEW Total Internal links: 1112
# [+] NEW Total: 1265
# [INT] Internal link: https://www.okcu.edu/uploads/human-resources/docs/Interim-Remote-Work-Plan-Policy.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/human-resources/docs/Remote-Work-Tips-for-Employees.pdf
# [INT] Internal link: https://www.okcu.edu/uploads/human-resources/docs/Remote-Work-Tips-for-Supervisors.pdf
# [+] NEW Total External links: 154
# [+] NEW Total Internal links: 1115
# [+] NEW Total: 1269
# [INT] Internal link: https://www.okcu.edu/campus/resources/cetl/resources/cetl-blog/p/when-campus-closes-but-learning-does-not-stop
# [+] NEW Total External links: 157
# [+] NEW Total Internal links: 1116
# [+] NEW Total: 1273
# [+] NEW Total External links: 158
# [+] NEW Total Internal links: 1116
# [+] NEW Total: 1274
# 28 1

# %%
def removeAfterN(yourStr, nth, occurenceOf):
    return occurenceOf.join(yourStr.split(occurenceOf)[:nth])

# %%
semifinal_immediate_urls = set()

for immediate_url in immediate_urls:
    stripped_url = removeAfterN(immediate_url,2,"http")
    
    
    semifinal_immediate_urls.add(stripped_url)
#     final_immediate_urls.add(rest)
#     print(rest)


    

print(semifinal_immediate_urls)
total_count = len(semifinal_immediate_urls)
print(total_count)
# Out:
# {'https://www.okcu.edu/main/coronavirus/policies/', 'https://www.okcu.edu/main/coronavirus/employees/', 'https://www.okcu.edu/main/coronavirus/news-communications/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/personal/', 'https://www.okcu.edu/main/coronavirus/ocu-safety-plan/', 'https://www.okcu.edu/main/coronavirus/health-resources/ask-a-question/', 'https://www.okcu.edu/main/coronavirus/health-resources/clinic/', 'https://www.okcu.edu/main/coronavirus/policies/face-coverings/', 'https://www.okcu.edu/main/coronavirus/policies/exposure-response-protocol/', 'https://www.okcu.edu/main/coronavirus/health-resources/risk-self-assessment-form/', 'https://www.okcu.edu/main/coronavirus/', 'https://www.okcu.edu/main/coronavirus/campus-visitors/', 'https://www.okcu.edu/main/coronavirus/health-resources/', 'https://www.okcu.edu/main/coronavirus/students/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/business/', 'https://www.okcu.edu/main/coronavirus/employees/retirement-plan-resources/', 'https://www.okcu.edu/main/coronavirus/employees/business-travel-registration/', 'https://www.okcu.edu/main/coronavirus/students/housing/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/', 'https://www.okcu.edu/main/coronavirus/employees/remote-work/', 'https://www.okcu.edu/main/coronavirus/policies/travel/students/', 'https://www.okcu.edu/main/coronavirus/students/healthcare-support/', 'https://www.okcu.edu/main/coronavirus/policies/travel/', 'https://www.okcu.edu/main/coronavirus/students/travel/', 'https://www.okcu.edu/main/coronavirus/employees/health-resources/', 'https://www.okcu.edu/main/coronavirus/employees/personal-travel-registration/', 'https://www.okcu.edu/main/coronavirus/employees/online-teaching/', 'https://www.okcu.edu/main/coronavirus/employees/self-assessment/'}
# 28

# %%
final_immediate_urls = set()
for semifinal_immediate_url in semifinal_immediate_urls:
    if "tel:" not in semifinal_immediate_url:
        final_immediate_urls.add(semifinal_immediate_url)

print(final_immediate_urls)
total_count = len(final_immediate_urls)
print(total_count)
# Out:
# {'https://www.okcu.edu/main/coronavirus/employees/', 'https://www.okcu.edu/main/coronavirus/news-communications/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/personal/', 'https://www.okcu.edu/main/coronavirus/ocu-safety-plan/', 'https://www.okcu.edu/main/coronavirus/health-resources/ask-a-question/', 'https://www.okcu.edu/main/coronavirus/employees/personal-travel-registration/', 'https://www.okcu.edu/main/coronavirus/health-resources/clinic/', 'https://www.okcu.edu/main/coronavirus/policies/face-coverings/', 'https://www.okcu.edu/main/coronavirus/policies/exposure-response-protocol/', 'https://www.okcu.edu/main/coronavirus/health-resources/risk-self-assessment-form/', 'https://www.okcu.edu/main/coronavirus/', 'https://www.okcu.edu/main/coronavirus/campus-visitors/', 'https://www.okcu.edu/main/coronavirus/health-resources/', 'https://www.okcu.edu/main/coronavirus/students/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/business/', 'https://www.okcu.edu/main/coronavirus/employees/retirement-plan-resources/', 'https://www.okcu.edu/main/coronavirus/employees/business-travel-registration/', 'https://www.okcu.edu/main/coronavirus/students/housing/', 'https://www.okcu.edu/main/coronavirus/policies/travel/employees/', 'https://www.okcu.edu/main/coronavirus/employees/remote-work/', 'https://www.okcu.edu/main/coronavirus/policies/travel/students/', 'https://www.okcu.edu/main/coronavirus/students/healthcare-support/', 'https://www.okcu.edu/main/coronavirus/policies/travel/', 'https://www.okcu.edu/main/coronavirus/students/travel/', 'https://www.okcu.edu/main/coronavirus/employees/health-resources/', 'https://www.okcu.edu/main/coronavirus/policies/', 'https://www.okcu.edu/main/coronavirus/employees/online-teaching/', 'https://www.okcu.edu/main/coronavirus/employees/self-assessment/'}
# 28

# %%
parent_folder = "Doctoral" #Change based on folder
name_of_folder = f'{base_url_text_domain}_Screenshots'
options = webdriver.ChromeOptions()
options.headless = True
driver = webdriver.Chrome(options=options,executable_path='chromedriver.exe') # #Local Path of chrome driver
if not os.path.exists(f'{parent_folder}\\{name_of_folder}'):
    os.makedirs(f'{parent_folder}\\{name_of_folder}')

# %%
webpage_save = set()
webpage_save_count = 0
webpage_cannot_save = 0
for i in final_immediate_urls:
    if ' ' in i:
        continue
    try:
        code=urlopen(i).getcode()
        webpage_save.add(i)
        webpage_save_count = webpage_save_count+1
        print(f"{code} can_save - {i}")
    except (urllib.error.HTTPError,urllib.error.URLError) as e:
        print("discarded")
        webpage_cannot_save = webpage_cannot_save+1
        continue

print(f'Webpages save as HTML :{webpage_save_count}')
print(f'Webpages unable to save as HTML :{webpage_cannot_save}')
# Out:
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/
# 200 can_save - https://www.okcu.edu/main/coronavirus/news-communications/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/travel/employees/personal/
# 200 can_save - https://www.okcu.edu/main/coronavirus/ocu-safety-plan/
# 200 can_save - https://www.okcu.edu/main/coronavirus/health-resources/ask-a-question/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/personal-travel-registration/
# 200 can_save - https://www.okcu.edu/main/coronavirus/health-resources/clinic/
# discarded
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/exposure-response-protocol/
# 200 can_save - https://www.okcu.edu/main/coronavirus/health-resources/risk-self-assessment-form/
# 200 can_save - https://www.okcu.edu/main/coronavirus/
# 200 can_save - https://www.okcu.edu/main/coronavirus/campus-visitors/
# 200 can_save - https://www.okcu.edu/main/coronavirus/health-resources/
# 200 can_save - https://www.okcu.edu/main/coronavirus/students/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/travel/employees/business/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/retirement-plan-resources/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/business-travel-registration/
# 200 can_save - https://www.okcu.edu/main/coronavirus/students/housing/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/travel/employees/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/remote-work/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/travel/students/
# 200 can_save - https://www.okcu.edu/main/coronavirus/students/healthcare-support/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/travel/
# 200 can_save - https://www.okcu.edu/main/coronavirus/students/travel/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/health-resources/
# 200 can_save - https://www.okcu.edu/main/coronavirus/policies/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/online-teaching/
# 200 can_save - https://www.okcu.edu/main/coronavirus/employees/self-assessment/
# Webpages save as HTML :27
# Webpages unable to save as HTML :1

# %%
pdf_count = 0
pdf_urls = set()
for webpage in webpage_save:
    if webpage[-4:] == ".pdf":
        url = webpage
        file_name = url.replace(base_url,'')
        file_name = file_name.replace('/','')
        if file_name == '':
            file_name = "Home"
        pdf_urls.add(webpage)
        print(webpage)
        r = requests.get(url, stream=True)
        with open(f'{parent_folder}\\{name_of_folder}\\{file_name}.pdf', 'wb') as fd:
            for chunk in r.iter_content(2000):
                fd.write(chunk)
        pdf_count = pdf_count + 1

print(f"Pdfs saved: {pdf_count}")
# Out:
# Pdfs saved: 0

# %%
final_immediate_urls = final_immediate_urls - pdf_urls
webpage_save = webpage_save - pdf_urls
web_save_count = len(webpage_save)
total_count = len(final_immediate_urls)
print(total_count)
# Out:
# 28

# %%
#     try:
#         print(i)
        
#         print("added")
#     except urllib.error.HTTPError as e:
#         if e.code in (400,403):
#             print("discarded")
#             continue

# %%
final_webpage_save_count = webpage_save_count - pdf_count
print(final_webpage_save_count)
# Out:
# 27

# %%
webpage_save_counter_loop = 0
for webpage in webpage_save:
    url = webpage
    file_name = url.replace(base_url,'')
    file_name = file_name.replace('/','')
    if file_name == '':
            file_name = "Home"
    urllib.request.urlretrieve (webpage, f"{parent_folder}\\{name_of_folder}\\{file_name}.html")
    webpage_save_counter_loop = webpage_save_counter_loop+1
    print(f'{webpage_save_counter_loop} of {final_webpage_save_count} - {webpage}')

print("Saving Completed")
# Out:
# 1 of 27 - https://www.okcu.edu/main/coronavirus/health-resources/
# 2 of 27 - https://www.okcu.edu/main/coronavirus/employees/
# 3 of 27 - https://www.okcu.edu/main/coronavirus/students/
# 4 of 27 - https://www.okcu.edu/main/coronavirus/policies/travel/employees/business/
# 5 of 27 - https://www.okcu.edu/main/coronavirus/news-communications/
# 6 of 27 - https://www.okcu.edu/main/coronavirus/employees/retirement-plan-resources/
# 7 of 27 - https://www.okcu.edu/main/coronavirus/policies/travel/employees/personal/
# 8 of 27 - https://www.okcu.edu/main/coronavirus/employees/business-travel-registration/
# 9 of 27 - https://www.okcu.edu/main/coronavirus/students/housing/
# 10 of 27 - https://www.okcu.edu/main/coronavirus/ocu-safety-plan/
# 11 of 27 - https://www.okcu.edu/main/coronavirus/health-resources/ask-a-question/
# 12 of 27 - https://www.okcu.edu/main/coronavirus/policies/travel/employees/
# 13 of 27 - https://www.okcu.edu/main/coronavirus/employees/remote-work/
# 14 of 27 - https://www.okcu.edu/main/coronavirus/policies/travel/students/
# 15 of 27 - https://www.okcu.edu/main/coronavirus/employees/personal-travel-registration/
# 16 of 27 - https://www.okcu.edu/main/coronavirus/health-resources/clinic/
# 17 of 27 - https://www.okcu.edu/main/coronavirus/students/healthcare-support/
# 18 of 27 - https://www.okcu.edu/main/coronavirus/policies/travel/
# 19 of 27 - https://www.okcu.edu/main/coronavirus/students/travel/
# 20 of 27 - https://www.okcu.edu/main/coronavirus/policies/exposure-response-protocol/
# 21 of 27 - https://www.okcu.edu/main/coronavirus/health-resources/risk-self-assessment-form/
# 22 of 27 - https://www.okcu.edu/main/coronavirus/employees/health-resources/
# 23 of 27 - https://www.okcu.edu/main/coronavirus/
# 24 of 27 - https://www.okcu.edu/main/coronavirus/policies/
# 25 of 27 - https://www.okcu.edu/main/coronavirus/campus-visitors/
# 26 of 27 - https://www.okcu.edu/main/coronavirus/employees/online-teaching/
# 27 of 27 - https://www.okcu.edu/main/coronavirus/employees/self-assessment/
# Saving Completed

# %%
count = 0
for i in final_immediate_urls:
    url = i
    file_name = url.replace(base_url,'')
    file_name = file_name.replace('/','')
    if file_name == '':
            file_name = "Home"
    count = count + 1
    print(f"{count} of {total_count}")
    print(f'Visiting {base_url_text}/{file_name}')
    print(f'...Taking a screenshot')
    driver.get(url)
    S = lambda X: driver.execute_script('return document.body.parentNode.scroll'+X)
    driver.set_window_size(S('Width'),S('Height')) # May need manual adjustment                                                                                                                
    driver.find_element_by_tag_name('body').screenshot(f'{parent_folder}\\{name_of_folder}\\{file_name}.png')
    print(f'Screenshot of {file_name} page taken! \n')
#     print("Saving HTML")
#     pyautogui.hotkey('ctrl', 's')
#     time.sleep(1)
#     pyautogui.typewrite(f'{file_name}.html')
#     pyautogui.hotkey('enter')
driver.quit()
    
print(f'Task Completed! Files stored in the {parent_folder}\\{name_of_folder} Folder')
# Out:
# 1 of 28
# Visiting www.okcu.edu/main/coronavirus//health-resources
# ...Taking a screenshot
# Screenshot of health-resources page taken!
#
# 2 of 28
# Visiting www.okcu.edu/main/coronavirus//policies
# ...Taking a screenshot
# Screenshot of policies page taken!
#
# 3 of 28
# Visiting www.okcu.edu/main/coronavirus//employees
# ...Taking a screenshot
# Screenshot of employees page taken!
#
# 4 of 28
# Visiting www.okcu.edu/main/coronavirus//students
# ...Taking a screenshot
# Screenshot of students page taken!
#
# 5 of 28
# Visiting www.okcu.edu/main/coronavirus//policiestravelemployeesbusiness
# ...Taking a screenshot
# Screenshot of policiestravelemployeesbusiness page taken!
#
# 6 of 28
# Visiting www.okcu.edu/main/coronavirus//news-communications
# ...Taking a screenshot
# Screenshot of news-communications page taken!
#
# 7 of 28
# Visiting www.okcu.edu/main/coronavirus//employeesretirement-plan-resources
# ...Taking a screenshot
# Screenshot of employeesretirement-plan-resources page taken!
#
# 8 of 28
# Visiting www.okcu.edu/main/coronavirus//policiestravelemployeespersonal
# ...Taking a screenshot
# Screenshot of policiestravelemployeespersonal page taken!
#
# 9 of 28
# Visiting www.okcu.edu/main/coronavirus//employeesbusiness-travel-registration
# ...Taking a screenshot
# Screenshot of employeesbusiness-travel-registration page taken!
#
# 10 of 28
# Visiting www.okcu.edu/main/coronavirus//studentshousing
# ...Taking a screenshot
# Screenshot of studentshousing page taken!
#
# 11 of 28
# Visiting www.okcu.edu/main/coronavirus//ocu-safety-plan
# ...Taking a screenshot
# Screenshot of ocu-safety-plan page taken!
#
# 12 of 28
# Visiting www.okcu.edu/main/coronavirus//health-resourcesask-a-question
# ...Taking a screenshot
# Screenshot of health-resourcesask-a-question page taken!
#
# 13 of 28
# Visiting www.okcu.edu/main/coronavirus//policiestravelemployees
# ...Taking a screenshot
# Screenshot of policiestravelemployees page taken!
#
# 14 of 28
# Visiting www.okcu.edu/main/coronavirus//employeesremote-work
# ...Taking a screenshot
# Screenshot of employeesremote-work page taken!
#
# 15 of 28
# Visiting www.okcu.edu/main/coronavirus//policiestravelstudents
# ...Taking a screenshot
# Screenshot of policiestravelstudents page taken!
#
# 16 of 28
# Visiting www.okcu.edu/main/coronavirus//health-resourcesclinic
# ...Taking a screenshot
# Screenshot of health-resourcesclinic page taken!
#
# 17 of 28
# Visiting www.okcu.edu/main/coronavirus//studentshealthcare-support
# ...Taking a screenshot
# Screenshot of studentshealthcare-support page taken!
#
# 18 of 28
# Visiting www.okcu.edu/main/coronavirus//policiesface-coverings
# ...Taking a screenshot
# Screenshot of policiesface-coverings page taken!
#
# 19 of 28
# Visiting www.okcu.edu/main/coronavirus//policiestravel
# ...Taking a screenshot
# Screenshot of policiestravel page taken!
#
# 20 of 28
# Visiting www.okcu.edu/main/coronavirus//studentstravel
# ...Taking a screenshot
# Screenshot of studentstravel page taken!
#
# 21 of 28
# Visiting www.okcu.edu/main/coronavirus//policiesexposure-response-protocol
# ...Taking a screenshot
# Screenshot of policiesexposure-response-protocol page taken!
#
# 22 of 28
# Visiting www.okcu.edu/main/coronavirus//health-resourcesrisk-self-assessment-form
# ...Taking a screenshot
# Screenshot of health-resourcesrisk-self-assessment-form page taken!
#
# 23 of 28
# Visiting www.okcu.edu/main/coronavirus//employeeshealth-resources
# ...Taking a screenshot
# Screenshot of employeeshealth-resources page taken!
#
# 24 of 28
# Visiting www.okcu.edu/main/coronavirus//Home
# ...Taking a screenshot
# Screenshot of Home page taken!
#
# 25 of 28
# Visiting www.okcu.edu/main/coronavirus//employeespersonal-travel-registration
# ...Taking a screenshot
# Screenshot of employeespersonal-travel-registration page taken!
#
# 26 of 28
# Visiting www.okcu.edu/main/coronavirus//campus-visitors
# ...Taking a screenshot
# Screenshot of campus-visitors page taken!
#
# 27 of 28
# Visiting www.okcu.edu/main/coronavirus//employeesonline-teaching
# ...Taking a screenshot
# Screenshot of employeesonline-teaching page taken!
#
# 28 of 28
# Visiting www.okcu.edu/main/coronavirus//employeesself-assessment
# ...Taking a screenshot
# Screenshot of employeesself-assessment page taken!
#
# Task Completed! Files stored in the Doctoral\www.okcu.edu_Screenshots Folder
