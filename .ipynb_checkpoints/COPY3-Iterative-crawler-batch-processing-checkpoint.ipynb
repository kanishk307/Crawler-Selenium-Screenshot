# %%
#Imports
import time
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import urllib.request
from urllib.request import urlopen
import pyautogui
import lxml.html
# from pywebcopy import save_webpage

# %%
internal_urls = set()
external_urls = set()

# %%
def is_url_valid(url):
   #Checks if the url is valid or not
    parsedURL = urlparse(url)
    return bool(parsedURL.netloc) and bool(parsedURL.scheme)

#The above function works as follows. We check if the scheme is present and there is a value in the network location part
# url = "https://umd.edu/virusinfo"
# urlparse(url)
# ParseResult(scheme='https', netloc='umd.edu', path='/virusinfo', 
# params='', query='', fragment='')

# %%
#The function gives all urls
def get_all_urls(url):
    urls = set()
    # domain name of the URL without the protocol (umd.edu in this case)
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            #href is empty and we don't need that a element
            continue
        #if the link is not absolute, make it by joining relative to the base
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        #constructing an absolute URL from parsed data
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_url_valid(href):
            #in valid url
            continue
        if href in internal_urls:
            #it is already in the set, so we don't need to add
            continue
        if domain_name not in href:
            #it is an external link. i.e
            # Check if it is already there 
            if href not in external_urls:
#                 print(f"[EXT] External link: {href}")
                external_urls.add(href)
            continue
#         print(".",end=" ")
        print(f"[INT] Internal link: {href}")

        urls.add(href)
        internal_urls.add(href)
    return urls

# %%
total_urls_visited = 0
def crawl(url, max_urls=50):
    #Max URL is just to decrease the time if there are a lot of pages.
    #The following code was openly available of github and I found this
    #idea useful to inhibit crawling time
    global total_urls_visited
    total_urls_visited += 1
    links = get_all_urls(url)
    for link in links:
        if total_urls_visited > max_urls:
            break
        crawl(link, max_urls=max_urls)

# %%
base_urls = ["https://covid.cornell.edu/"]
parent_folder = "Doctoral" #Doctoral, Masters, Bach

# %%
for base_url in base_urls:
    parsedurl = urlparse(base_url)
    # base_url_text = base_url.split("//",1)[1]
    base_url_text = parsedurl.netloc+parsedurl.path
    print(base_url_text)
    # base_url_text_domain = base_url_text.split("/",1)[0]
    base_url_text_domain = parsedurl.netloc
    print(base_url_text_domain)
    crawl(base_url)
    print("[+] Total External links:", len(external_urls))
    print("[+] Total Internal links:", len(internal_urls))
    print("[+] Total:", len(external_urls) + len(internal_urls))
    
    
    count = 0
    last_count = 989874
    immediate_urls = set() #Linked Associated with the current page, https://umd.edu/virusinfo/ in this case

    for i in range(0,5):
        for url in internal_urls:
            if base_url_text in url:
                immediate_urls.add(url)
        count = len(immediate_urls)
        if(count == last_count):
            break
        last_count = count
        print(count,i)
        for immediate_url in immediate_urls:
            crawl(immediate_url)
            print("[+] NEW Total External links:", len(external_urls))
            print("[+] NEW Total Internal links:", len(internal_urls))
            print("[+] NEW Total:", len(external_urls) + len(internal_urls))
        
        
    def removeAfterN(yourStr, nth, occurenceOf):
        return occurenceOf.join(yourStr.split(occurenceOf)[:nth])

    semifinal_immediate_urls = set()
    for immediate_url in immediate_urls:
        stripped_url = removeAfterN(immediate_url,2,"http")
        semifinal_immediate_urls.add(stripped_url)
    #     final_immediate_urls.add(rest)
    #     print(rest)

    print(semifinal_immediate_urls)
    total_count = len(semifinal_immediate_urls)
    print(total_count)
    
    final_immediate_urls = set()
    for semifinal_immediate_url in semifinal_immediate_urls:
        if "tel:" not in semifinal_immediate_url:
            final_immediate_urls.add(semifinal_immediate_url)

    print(final_immediate_urls)
    total_count = len(final_immediate_urls)
    print(total_count)
    
    name_of_folder = f'{base_url_text_domain}_Screenshots'
    options = webdriver.ChromeOptions()
    options.headless = True
    driver = webdriver.Chrome(options=options,executable_path='chromedriver.exe') # #Local Path of chrome driver
    if not os.path.exists(f'{parent_folder}\\{name_of_folder}'):
        os.makedirs(f'{parent_folder}\\{name_of_folder}')
    
    webpage_save = set()
    webpage_save_count = 0
    webpage_cannot_save = 0
    for i in final_immediate_urls:
        if ' ' in i:
            continue
        try:
            code=urlopen(i).getcode()
            webpage_save.add(i)
            webpage_save_count = webpage_save_count+1
            print(f"{code} can_save - {i}")
        except urllib.error.HTTPError as e:
            if e.code not in (200):
                webpage_cannot_save = webpage_cannot_save + 1
                print(f'{e.code} cannot_save - {i}')
                continue

    print(f'Webpages save as HTML :{webpage_save_count}')
    print(f'Webpages unable to save as HTML :{webpage_cannot_save}')

    pdf_count = 0
    pdf_urls = set()
    for webpage in webpage_save:
        if webpage[-4:] == ".pdf":
            url = webpage
            file_name = url.replace(base_url,'')
            file_name = file_name.replace('/','')
            if file_name == '':
                file_name = "Home"
            pdf_urls.add(webpage)
            print(webpage)
            r = requests.get(url, stream=True)
            with open(f'{parent_folder}\\{name_of_folder}\\{file_name}.pdf', 'wb') as fd:
                for chunk in r.iter_content(2000):
                    fd.write(chunk)
            pdf_count = pdf_count + 1

    print(f"Pdfs saved: {pdf_count}")
    
    final_immediate_urls = final_immediate_urls - pdf_urls
    webpage_save = webpage_save - pdf_urls
    web_save_count = len(webpage_save)
    total_count = len(final_immediate_urls)
    print(total_count) 
    
    
    webpage_save_counter_loop = 0
    for webpage in webpage_save:
        url = webpage
        file_name = url.replace(base_url,'')
        file_name = file_name.replace('/','')
        if file_name == '':
                file_name = "Home"
        urllib.request.urlretrieve (webpage, f"{parent_folder}\\{name_of_folder}\\{file_name}.html")
        webpage_save_counter_loop = webpage_save_counter_loop+1
        print(f'{webpage_save_counter_loop} of {webpage_save_count} - {webpage}')

    print("Saving Completed")
    
    
    count = 0
    for i in final_immediate_urls:
        url = i
        file_name = url.replace(base_url,'')
        file_name = file_name.replace('/','')
        if file_name == '':
                file_name = "Home"
        count = count + 1
        print(f"{count} of {total_count}")
        print(f'Visiting {base_url_text}/{file_name}')
        print(f'...Taking a screenshot')
        driver.get(url)
        S = lambda X: driver.execute_script('return document.body.parentNode.scroll'+X)
        driver.set_window_size(S('Width'),S('Height')) # May need manual adjustment                                                                                                                
        driver.find_element_by_tag_name('body').screenshot(f'{parent_folder}\\{name_of_folder}\\{file_name}.png')
        print(f'Screenshot of {file_name} page taken! \n')
    #     print("Saving HTML")
    #     pyautogui.hotkey('ctrl', 's')
    #     time.sleep(1)
    #     pyautogui.typewrite(f'{file_name}.html')
    #     pyautogui.hotkey('enter')
    
    driver.quit()
    print(f'Task Completed! Files stored in the {parent_folder}\\{name_of_folder} Folder')

    print("------------------------END-------------------------------\n")
# Out:
# covid.cornell.edu/
# covid.cornell.edu
# [INT] Internal link: https://covid.cornell.edu/
# [INT] Internal link: https://covid.cornell.edu/students/
# [INT] Internal link: https://covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/staff/
# [INT] Internal link: https://covid.cornell.edu/updates/
# [INT] Internal link: https://covid.cornell.edu/students/academic-calendar/
# [INT] Internal link: https://covid.cornell.edu/students/academic-policies/
# [INT] Internal link: https://covid.cornell.edu/students/online-instruction/
# [INT] Internal link: https://covid.cornell.edu/students/housing-dining/
# [INT] Internal link: https://covid.cornell.edu/students/student-health/
# [INT] Internal link: https://covid.cornell.edu/students/international-students/
# [INT] Internal link: https://covid.cornell.edu/students/graduate-students/
# [INT] Internal link: https://covid.cornell.edu/students/financial-matters/
# [INT] Internal link: https://covid.cornell.edu/students/advising/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/staff/reentry/
# [INT] Internal link: https://covid.cornell.edu/staff/workplace-accommodations/
# [INT] Internal link: https://covid.cornell.edu/staff/responsibilities/
# [INT] Internal link: https://covid.cornell.edu/staff/facilities-personnel/
# [INT] Internal link: https://covid.cornell.edu/staff/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/research-continuity/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/cares-act/
# [INT] Internal link: https://covid.cornell.edu/events/
# [INT] Internal link: https://covid.cornell.edu/travel/
# [INT] Internal link: https://covid.cornell.edu/transportation/
# [INT] Internal link: https://covid.cornell.edu/operations/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/updates/20200630-reactivate-campus.cfm
# [INT] Internal link: https://covid.cornell.edu/updates/20200522-research-reactiviation-planning.cfm
# [INT] Internal link: https://covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/students
# [INT] Internal link: https://covid.cornell.edu/faculty
# [INT] Internal link: https://covid.cornell.edu/staff
# [INT] Internal link: https://covid.cornell.edu/visitors
# [INT] Internal link: https://covid.cornell.edu/prevention/support
# [INT] Internal link: https://covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/resources/graphics/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/reactivation/daily-check/ https:/covid.cornell.edu/reactivation/guidelines/ https:/covid.cornell.edu/resources/health/ https:/covid.cornell.edu/faculty/ https:/covid.cornell.edu/prevention/face-coverings/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/prevention/ https:/covid.cornell.edu/visitors/ https:/covid.cornell.edu/resources/graphics/
# [+] Total External links: 4
# [+] Total Internal links: 192
# [+] Total: 196
# 192 0
# [+] NEW Total External links: 4
# [+] NEW Total Internal links: 192
# [+] NEW Total: 196
# [+] NEW Total External links: 4
# [+] NEW Total Internal links: 192
# [+] NEW Total: 196
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/faculty/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/visitors/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/reactivation/principles/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/reactivation/guidelines/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/reactivation/committees/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/reactivation/daily-check/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/prevention/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/prevention/support/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/prevention/face-coverings/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/prevention/cleaning/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/resources/health/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/resources/technology/
# [INT] Internal link: https://covid.cornell.edu/ https:/covid.cornell.edu/prevention/cleaning/ https:/covid.cornell.edu/resources/graphics/
# [+] NEW Total External links: 4
# [+] NEW Total Internal links: 205
# [+] NEW Total: 209
